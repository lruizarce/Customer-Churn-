# %%
import os
import pickle
import numpy as np
import pandas as pd
import streamlit as st
from openai import OpenAI

# Retrieve the API key from the environment variable
api_key = os.environ.get("GROQ_API_KEY")

if not api_key:
    raise ValueError("GROQ_API_KEY environment variable is not set.")

# Initialize the OpenAI client
client = OpenAI(base_url="https://api.groq.com/openai/v1", api_key=api_key)


# Load model function
def load_model(filename):
    with open(filename, "rb") as file:
        return pickle.load(file)


# Load models
xgboost_model = load_model("../models/xgb_model.pkl")
dc_model = load_model("../models/dc_model.pkl")
nb_model = load_model("../models/nb_model.pkl")
rf_model = load_model("../models/rf_model.pkl")
voting_model = load_model("../models/voting_clf.pkl")
voting_hard_model = load_model("../models/xgb_model.pkl")
xgboost_feature = load_model("../models/xgboost_feature_engineering.pkl")
xgboost_smote = load_model("../models/xgboost-SMOTE.pkl")
kn_model = load_model("../models/kn_model.pkl")


# Prepare input data for prediction
def prepare_input(
    credit_score,
    location,
    gender,
    age,
    tenure,
    balance,
    num_products,
    has_credit_card,
    is_active_member,
    estimated_salary,
):
    input_dict = {
        "CreditScore": credit_score,
        "Age": age,
        "Tenure": tenure,
        "Balance": balance,
        "NumOfProducts": num_products,
        "HasCrCard": int(has_credit_card),
        "IsActiveMember": int(is_active_member),
        "EstimatedSalary": estimated_salary,
        "Geography_France": 1 if location == "France" else 0,
        "Geography_Germany": 1 if location == "German" else 0,
        "Geography_Spain": 1 if location == "Spain" else 0,
        "Gender_Male": 1 if gender == "Male" else 0,
        "Gender_Female": 1 if gender == "Female" else 0,
    }
    input_df = pd.DataFrame([input_dict])
    return input_df, input_dict


# Make predictions and display results
def make_predictions(input_df, input_dict):
    probabilities = {
        "XGBoost": xgboost_model.predict_proba(input_df)[0][1],
        "Random Forest": rf_model.predict_proba(input_df)[0][1],
        "K-Nearest Neighbors": kn_model.predict_proba(input_df)[0][1],
    }
    avg_probabilities = np.mean(list(probabilities.values()))

    st.markdown("### Model Probabilities")
    for model, prob in probabilities.items():
        st.write(f"{model}: {prob}")
    st.write(f"Average probability: {avg_probabilities}")
    return avg_probabilities


# Explain predictions using the OpenAI client
def explain_predictions(probability, input_dict, surname):
    prompt = f"""
    You are an expert data scientist at a bank, where you specialize in interpreting and explaining predictions of machine learning models.

    Your machine learning model has predicted that a customer named {surname} has a {round(probability * 100, 1)}% probability of churning, based on the information provided below.

    Here are the machine learning model's top 100 important features for predicting churn:

    Feature | Importance
    --------------------
    NumOfProducts    | 0.323888
    IsActiveMember   | 0.164146
    Age              | 0.109550
    Geography_German | 0.091373
    Balance          | 0.052786
    Geography_France | 0.046463
    Gender_Female    | 0.045283
    CreditScore      | 0.036855
    EstimatedSalary  | 0.032655
    HasCrCard        | 0.031940
    Tenure           | 0.030054
    Gender_Female    | 0.000000

    Here are summary statistics for churned customers
    {df[df['Exited'] == 0].describe()}

    Here are summary statistics for non-churned customers
    {df[df['Exited'] == 1].describe()}

    - If the customer has over 30% risk of churning, generate a 3-sentence explanation of why they are at risk.
    - If the customer has less than a 40% risk of churning, generate a 3-sentence explanation why they are not at risk.
    - Your explanations should be based on the customer's information, the summary statistics of churned and non-churned customers, and the feature importances provided.
    """

    response = client.chat.completions.create(
        model="llama-3.2-3b-preview", messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content


def generate_email(probability, input_dict, explanation, surname):
    prompt = f"""You are an expert at handling client relationships. You are responsible for ensuring customers stay with your bank and are incentived with various offers.
    
    You noticed a customer named {surname} has a {round(probability* 100, 1)}% probability of churning.
    
    Here is some explanation as to why the customer might be at risk of churning:
    {explanation}
    
    Generate an email to the customer based on their information, asking them to stay if they are at risk of churning, or offering them incentives so that they become more loyal to the bank.
    
    Make sure to list out a set of incentives to stay based on their information, in bullet point format. Don't ever mention the probability of churning, or the machine learning model to the customer.
    """
    raw_response = client.chat.completions.create(
        model="llama-3.1-8b-instant", messages=[{"role": "user", "content": prompt}]
    )

    print("\n\nEMAIL PROMPT", prompt)

    return raw_response.choices[0].message.content


# Streamlit app setup
st.title("Customer Churn Prediction")
df = pd.read_csv("../data/churn.csv")

customers = [f"{row['CustomerId']} - {row['Surname']}" for _, row in df.iterrows()]
selected_customer_option = st.selectbox("Select a customer", customers)

if selected_customer_option:
    selected_customer_id = int(selected_customer_option.split("-")[0])
    selected_surname = selected_customer_option.split("-")[1]
    selected_customer = df.loc[df["CustomerId"] == selected_customer_id].iloc[0]

    col1, col2 = st.columns(2)
    with col1:
        credit_score = st.number_input(
            "Credit Score",
            min_value=300,
            max_value=800,
            value=int(selected_customer["CreditScore"]),
        )
        location = st.selectbox(
            "Location",
            ["Spain", "France", "Germany"],
            index=["Spain", "France", "Germany"].index(selected_customer["Geography"]),
        )
        gender = st.radio(
            "Gender",
            ["Male", "Female"],
            index=0 if selected_customer["Gender"] == "Male" else 1,
        )
        age = st.number_input(
            "Age", min_value=18, max_value=100, value=int(selected_customer["Age"])
        )
        tenure = st.number_input(
            "Tenure (years)",
            min_value=0,
            max_value=50,
            value=int(selected_customer["Tenure"]),
        )

    with col2:
        balance = st.number_input(
            "Balance", min_value=0.0, value=float(selected_customer["Balance"])
        )
        num_of_products = st.number_input(
            "Number of Services",
            min_value=1,
            max_value=10,
            value=int(selected_customer["NumOfProducts"]),
        )
        has_credit_card = st.checkbox(
            "Has Credit Card", value=bool(selected_customer["HasCrCard"])
        )
        is_active_member = st.checkbox(
            "Is Active member", value=bool(selected_customer["IsActiveMember"])
        )
        estimated_salary = st.number_input(
            "Estimated Salary",
            min_value=0.0,
            value=float(selected_customer["EstimatedSalary"]),
        )

    input_df, input_dict = prepare_input(
        credit_score,
        location,
        gender,
        age,
        tenure,
        balance,
        num_of_products,
        has_credit_card,
        is_active_member,
        estimated_salary,
    )
    avg_probabilities = make_predictions(input_df, input_dict)

    explanation = explain_predictions(
        avg_probabilities, input_dict, selected_customer["Surname"]
    )
    st.markdown("---")
    st.subheader("Explanation of Prediction")
    st.markdown(explanation)
    
    email = generate_email(avg_probabilities, input_dict, explanation, selected_customer['Surname'])
    
    st.markdown("---")
    st.subheader("Personalized Email")
    st.markdown(email)
# Out:
# 2024-10-20 22:21:52.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:52.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.295 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# c:\Users\luisr\Desktop\headstarter\.venv\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\luisr\Desktop\headstarter\.venv\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# 2024-10-20 22:21:53.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.344 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:53.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.966 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.967 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:54.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# EMAIL PROMPT You are an expert at handling client relationships. You are responsible for ensuring customers stay with your bank and are incentived with various offers.
#
#     You noticed a customer named Hargrave has a 11.5% probability of churning.
#
#     Here is some explanation as to why the customer might be at risk of churning:
#     Based on the provided confidence score of 11.5% for customer Hargrave, which is greater than 30%, here's a 3-sentence explanation of why they are at risk of churning:
#
# Customer Hargrave appears to have a higher propensity for churning due to their high credit score (credit score is the 6th most important feature in the model with a score of 0.036855), which may indicate that they are more cautious with their finances and may be more likely to down-grade their credit profile in response to a negative experience with the bank. Additionally, Hargrave's employment tenure (tenure) is 37.4 months, which is within the lower 10th percentile among churned customers but still slightly above the median. As a result, the model has provided a high probability of retention, and further analysis or targeted interventions may be necessary to mitigate the risk of churn.
#
# If the customer has less than a 40% risk of churning, here's a 3-sentence explanation of why they are not at risk:
#
# Customer Hargrave has a relatively low risk of churning, primarily due to their high age (age is the 4th most important feature in the model with a score of 0.109550), which suggests that they are financially stable and in a long-term relationship with the bank. Furthermore, Hargrave's employment tenure (tenure) is 37.4 months, which is above the median and relatively high-compared to the churned customers, indicating that they are likely to continue using the bank's services in the near future. Based on the model's predictions, customer Hargrave can be considered a low-risk customer, and proactive retention strategies may be less necessary.
#
# To implement these explanations, you can use a combination of data manipulation and machine learning model scoring.
#
#     Generate an email to the customer based on their information, asking them to stay if they are at risk of churning, or offering them incentives so that they become more loyal to the bank.
#
#     Make sure to list out a set of incentives to stay based on their information, in bullet point format. Don't ever mention the probability of churning, or the machine learning model to the customer.
