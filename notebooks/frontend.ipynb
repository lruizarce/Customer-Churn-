# %%
import os
import pickle
import numpy as np
import pandas as pd
import streamlit as st
from openai import OpenAI

# Retrieve the API key from the environment variable
api_key = os.environ.get("GROQ_API_KEY")

if not api_key:
    raise ValueError("GROQ_API_KEY environment variable is not set.")

# Initialize the OpenAI client
client = OpenAI(base_url="https://api.groq.com/openai/v1", api_key=api_key)


# Load model function
def load_model(filename):
    with open(filename, "rb") as file:
        return pickle.load(file)


# Load models
xgboost_model = load_model("../models/xgb_model.pkl")
dc_model = load_model("../models/dc_model.pkl")
nb_model = load_model("../models/nb_model.pkl")
rf_model = load_model("../models/rf_model.pkl")
voting_model = load_model("../models/voting_clf.pkl")
voting_hard_model = load_model("../models/xgb_model.pkl")
xgboost_feature = load_model("../models/xgboost_feature_engineering.pkl")
xgboost_smote = load_model("../models/xgboost-SMOTE.pkl")
kn_model = load_model("../models/kn_model.pkl")


# Prepare input data for prediction
def prepare_input(
    credit_score,
    location,
    gender,
    age,
    tenure,
    balance,
    num_products,
    has_credit_card,
    is_active_member,
    estimated_salary,
):
    input_dict = {
        "CreditScore": credit_score,
        "Age": age,
        "Tenure": tenure,
        "Balance": balance,
        "NumOfProducts": num_products,
        "HasCrCard": int(has_credit_card),
        "IsActiveMember": int(is_active_member),
        "EstimatedSalary": estimated_salary,
        "Geography_France": 1 if location == "France" else 0,
        "Geography_Germany": 1 if location == "German" else 0,
        "Geography_Spain": 1 if location == "Spain" else 0,
        "Gender_Male": 1 if gender == "Male" else 0,
        "Gender_Female": 1 if gender == "Female" else 0,
    }
    input_df = pd.DataFrame([input_dict])
    return input_df, input_dict


# Make predictions and display results
def make_predictions(input_df, input_dict):
    probabilities = {
        "XGBoost": xgboost_model.predict_proba(input_df)[0][1],
        "Random Forest": rf_model.predict_proba(input_df)[0][1],
        "K-Nearest Neighbors": kn_model.predict_proba(input_df)[0][1],
    }
    avg_probabilities = np.mean(list(probabilities.values()))

    st.markdown("### Model Probabilities")
    for model, prob in probabilities.items():
        st.write(f"{model}: {prob}")
    st.write(f"Average probability: {avg_probabilities}")
    return avg_probabilities


# Explain predictions using the OpenAI client
def explain_predictions(probability, input_dict, surname):
    prompt = f"""
    You are an expert data scientist at a bank, where you specialize in interpreting and explaining predictions of machine learning models.

    Your machine learning model has predicted that a customer named {surname} has a {round(probability * 100, 1)}% probability of churning, based on the information provided below.

    Here are the machine learning model's top 100 important features for predicting churn:

    Feature | Importance
    --------------------
    NumOfProducts    | 0.323888
    IsActiveMember   | 0.164146
    Age              | 0.109550
    Geography_German | 0.091373
    Balance          | 0.052786
    Geography_France | 0.046463
    Gender_Female    | 0.045283
    CreditScore      | 0.036855
    EstimatedSalary  | 0.032655
    HasCrCard        | 0.031940
    Tenure           | 0.030054
    Gender_Female    | 0.000000

    Here are summary statistics for churned customers
    {df[df['Exited'] == 0].describe()}

    Here are summary statistics for non-churned customers
    {df[df['Exited'] == 1].describe()}

    - If the customer has over 30% risk of churning, generate a 3-sentence explanation of why they are at risk.
    - If the customer has less than a 40% risk of churning, generate a 3-sentence explanation why they are not at risk.
    - Your explanations should be based on the customer's information, the summary statistics of churned and non-churned customers, and the feature importances provided.
    """

    response = client.chat.completions.create(
        model="llama-3.2-3b-preview", messages=[{"role": "user", "content": prompt}]
    )
    return response.choices[0].message.content


def generate_email(probability, input_dict, explanation, surname):
    prompt = f"""You are an expert at handling client relationships. You are responsible for ensuring customers stay with your bank and are incentived with various offers.
    
    You noticed a customer named {surname} has a {round(probability* 100, 1)}% probability of churning.
    
    Here is some explanation as to why the customer might be at risk of churning:
    {explanation}
    
    Generate an email to the customer based on their information, asking them to stay if they are at risk of churning, or offering them incentives so that they become more loyal to the bank.
    
    Make sure to list out a set of incentives to stay based on their information, in bullet point format. Don't ever mention the probability of churning, or the machine learning model to the customer.
    """
    raw_response = client.chat.completions.create(
        model="llama-3.1-8b-instant", messages=[{"role": "user", "content": prompt}]
    )

    print("\n\nEMAIL PROMPT", prompt)

    return raw_response.choices[0].message.content


# Streamlit app setup
st.title("Customer Churn Prediction")
df = pd.read_csv("../data/churn.csv")

customers = [f"{row['CustomerId']} - {row['Surname']}" for _, row in df.iterrows()]
selected_customer_option = st.selectbox("Select a customer", customers)

if selected_customer_option:
    selected_customer_id = int(selected_customer_option.split("-")[0])
    selected_surname = selected_customer_option.split("-")[1]
    selected_customer = df.loc[df["CustomerId"] == selected_customer_id].iloc[0]

    col1, col2 = st.columns(2)
    with col1:
        credit_score = st.number_input(
            "Credit Score",
            min_value=300,
            max_value=800,
            value=int(selected_customer["CreditScore"]),
        )
        location = st.selectbox(
            "Location",
            ["Spain", "France", "Germany"],
            index=["Spain", "France", "Germany"].index(selected_customer["Geography"]),
        )
        gender = st.radio(
            "Gender",
            ["Male", "Female"],
            index=0 if selected_customer["Gender"] == "Male" else 1,
        )
        age = st.number_input(
            "Age", min_value=18, max_value=100, value=int(selected_customer["Age"])
        )
        tenure = st.number_input(
            "Tenure (years)",
            min_value=0,
            max_value=50,
            value=int(selected_customer["Tenure"]),
        )

    with col2:
        balance = st.number_input(
            "Balance", min_value=0.0, value=float(selected_customer["Balance"])
        )
        num_of_products = st.number_input(
            "Number of Services",
            min_value=1,
            max_value=10,
            value=int(selected_customer["NumOfProducts"]),
        )
        has_credit_card = st.checkbox(
            "Has Credit Card", value=bool(selected_customer["HasCrCard"])
        )
        is_active_member = st.checkbox(
            "Is Active member", value=bool(selected_customer["IsActiveMember"])
        )
        estimated_salary = st.number_input(
            "Estimated Salary",
            min_value=0.0,
            value=float(selected_customer["EstimatedSalary"]),
        )

    input_df, input_dict = prepare_input(
        credit_score,
        location,
        gender,
        age,
        tenure,
        balance,
        num_of_products,
        has_credit_card,
        is_active_member,
        estimated_salary,
    )
    avg_probabilities = make_predictions(input_df, input_dict)

    explanation = explain_predictions(
        avg_probabilities, input_dict, selected_customer["Surname"]
    )
    st.markdown("---")
    st.subheader("Explanation of Prediction")
    st.markdown(explanation)
    
    email = generate_email(avg_probabilities, input_dict, explanation, selected_customer['Surname'])
    
    st.markdown("---")
    st.subheader("Personalized Email")
    st.markdown(email)
# Out:
# 2024-10-20 22:21:29.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:29.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.027 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.030 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.031 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.034 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# c:\Users\luisr\Desktop\headstarter\.venv\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# c:\Users\luisr\Desktop\headstarter\.venv\lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# 2024-10-20 22:21:30.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.081 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-10-20 22:21:30.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 233
#     230 st.subheader("Explanation of Prediction")
#     231 st.markdown(explanation)
# --> 233 email = generate_email(avg_probabilities, input_dict, explanation, selected_customer['Surname'])
#     235 st.markdown("---")
#     236 st.subheader("Personalized Email")
#
# Cell In[4], line 136, in generate_email(probability, input_dict, explanation, surname)
#     124 def generate_email(probability, input_dict, explanation, surname):
#     125     prompt = f"""You are an expert at handling client relationships. You are responsible for ensuring customers stay with your bank and are incentived with various offers.
#     126
#     127     You noticed a customer named {surname} has a {round(probability* 100, 1)}% probability of churning.
#    (...)
#     134     Make sure to list out a set of incentives to stay based on their information, in bullet point format. Don't ever mention the probability of churning, or the machine learning model to the customer.
#     135     """
# --> 136     raw_response = client.chat.completions.create(
#     137         model = "llama-3.1-8b-instant",
#     138         messsage =[{
#     139             'role': 'user',
#     140             'content': prompt
#     141         }]
#     142     )
#     144     print("\n\nEMAIL PROMPT", prompt)
#     146     return raw_response.choices[0].message.content
#
# File c:\Users\luisr\Desktop\headstarter\.venv\lib\site-packages\openai\_utils\_utils.py:273, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     271         else:
#     272             msg = f"Missing required argument: {quote(missing[0])}"
# --> 273     raise TypeError(msg)
#     274 return func(*args, **kwargs)
#
# TypeError: Missing required arguments; Expected either ('messages' and 'model') or ('messages', 'model' and 'stream') arguments to be given
